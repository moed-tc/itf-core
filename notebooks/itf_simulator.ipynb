# %% [markdown]
# # ITF Simulator (PINN-ready)
# This notebook will run symbolic and numerical tests for the Inertia of Time Framework.
#
# **To do:**
# - Import itf_core
# - Define temporal geometry
# - Build PINN loss structure
# - Test convergence
